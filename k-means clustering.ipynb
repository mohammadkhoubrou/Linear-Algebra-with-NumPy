# %%
import numpy as np

# %%
def k_means(vectors, k):
    centroids = vectors[np.random.choice(vectors.shape[0], k, replace=False)]
    clusters = [[] for i in range(k)]
    for i in vectors:
        distance = [np.linalg.norm(i - j) for j in centroids]
        clusters[np.argmin(distance)].append(min(distance))
    
    new_centroids = np.array(np.mean(cluster, axis=0) for cluster in clusters)
    
    if np.all(new_centroids == centroids):
        pass
    
    centroids == new_centroids

    return centroids, clusters

# %%
vectors = np.random.randint(5, size=(150,2))

# %%
k_means(vectors,3)
# Out:
# (array([[2, 3],
#         [2, 2],
#         [3, 3]]),
#  [[0.0,
#    2.0,
#    1.4142135623730951,
#    1.4142135623730951,
#    1.4142135623730951,
#    1.0,
#    1.4142135623730951,
#    1.0,
#    2.0,
#    0.0,
#    1.0,
#    0.0,
#    2.23606797749979,
#    2.0,
#    2.23606797749979,
#    2.23606797749979,
#    2.0,
#    1.4142135623730951,
#    0.0,
#    0.0,
#    2.0,
#    0.0,
#    0.0,
#    0.0,
#    0.0,
#    2.23606797749979,
#    2.0,
#    1.0,
#    1.0,
#    1.0,
#    2.0,
#    2.0,
#    1.0,
#    2.23606797749979,
#    1.4142135623730951,
#    2.23606797749979],
#   [1.4142135623730951,
#    2.23606797749979,
#    1.4142135623730951,
#    2.0,
#    1.0,
#    2.23606797749979,
#    1.4142135623730951,
#    1.0,
#    1.0,
#    2.8284271247461903,
#    1.4142135623730951,
#    1.4142135623730951,
#    1.4142135623730951,
#    2.0,
#    1.4142135623730951,
#    2.0,
#    2.8284271247461903,
#    2.23606797749979,
#    2.23606797749979,
#    1.0,
#    1.0,
#    2.0,
# ...
